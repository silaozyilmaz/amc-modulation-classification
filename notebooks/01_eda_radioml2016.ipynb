# %% [markdown]
# # EDA: RadioML 2016.10a
#
# **Amaç:** Veri setinin yapısını, dağılımlarını ve örnek sinyalleri incelemek.
#
# **Faz:** Phase 2 — Data Inventory & Exploratory Data Analysis

# %% [markdown]
# ## Planlanan Adımlar
#
# 1. **Veri yükleme** — Pickle dosyasını oku, `config.RML2016_PATH` kullan
# 2. **Yapı incelemesi** — Key/value şekilleri, dtype, örnek key'ler
# 3. **Modülasyon listesi** — 11 sınıf adı
# 4. **SNR dağılımı** — 20 seviye, aralık -20..+18 dB
# 5. **Sınıf dağılımı** — Her modülasyon için örnek sayısı
# 6. **SNR başına örnek sayısı** — Dengelilik kontrolü
# 7. **Waveform örnekleri** — Birkaç (mod, SNR) için I ve Q grafiği
# 8. **Constellation örnekleri** (opsiyonel) — I vs Q scatter
# 9. **Özet** — Bulgular ve EDA yorumları

# %% [markdown]
# ## 1. Veri Yükleme
#
# *(Yükleme kodu buraya eklenecek — `src.data.load_radioml2016` veya doğrudan pickle)*

# %%
# import pickle
# import sys
# sys.path.insert(0, '..')
# from config import RML2016_PATH
# 
# with open(RML2016_PATH, 'rb') as f:
#     Xd = pickle.load(f)
# print('Yüklendi.')

# %% [markdown]
# ## 2–9. Analiz Hücreleri
#
# *(Her adım için ayrı hücreler eklenecek)*
